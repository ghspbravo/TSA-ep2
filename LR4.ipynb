# %% [markdown]
# # ОБРАБОТКА ВРЕМЕННЫХ РЯДОВ НА ОСНОВЕ МНОГОМЕРНЫХ ДАННЫХ
# ---
# Кабанов Евгений, РИМ-281226

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = (13,8)


from openpyxl import load_workbook

# %%
DATA_PATH = '/Users/spbravo/Downloads/airline_flights_data_ord.xlsx'

# %%
wb = load_workbook(DATA_PATH)
sheet = wb.active

# %%
flights = []
holidays = []
costs = []

for col in sheet["H"]:
    flights.append(col.value)

for col in sheet["J"]:
    holidays.append(col.value)

for col in sheet["Q"]:
    costs.append(col.value)

# %%
flights[2:-2]
# Out:
# [datetime.datetime(2017, 1, 17, 0, 0),
#  datetime.datetime(2017, 1, 17, 0, 0),
#  datetime.datetime(2017, 1, 25, 0, 0),
#  datetime.datetime(2017, 1, 25, 0, 0),
#  datetime.datetime(2017, 1, 25, 0, 0),
#  datetime.datetime(2017, 1, 27, 0, 0),
#  datetime.datetime(2017, 1, 30, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
#  datetime.datetime(2017, 1, 31, 0, 0),
# ...
